# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense, concatenate
from sklearn.model_selection import train_test_split
from keras.models import load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.layers import Concatenate

# %% [markdown]
# # 데이터로드

# %%
df1 = pd.read_csv('21-01-01~22-12-31강진면.csv')

# %%
df2 = pd.read_csv('21-01-01~22-12-31신덕.csv')

# %%
df3 = pd.read_csv('21-01-01~22-12-31곡성.csv')

# %%
w_df = pd.read_csv('가탄교수위.csv')

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(w_df.shape)
# Out:
# (17520, 10)
# (17520, 10)
# (17520, 10)
# (17523, 2)

# %%
w_df = w_df.loc[38:]

# %%
w_df
# Out:
#                      일시   수위
# 38     2021-01-02 15:00  0.6
# 39     2021-01-02 16:00  0.6
# 40     2021-01-02 17:00  0.6
# 41     2021-01-02 18:00  0.6
# 42     2021-01-02 19:00  0.6
# ...                 ...  ...
# 17518  2022-12-31 23:00  0.6
# 17519  2022-12-31 24:00  0.6
# 17520  2023-01-01 01:00  0.6
# 17521  2023-01-01 02:00  0.6
# 17522  2023-01-01 03:00  0.6
#
# [17485 rows x 2 columns]
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:137: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:137: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:26: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:26: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:75: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:75: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:26: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.savefig(
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:26: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   plt.savefig(
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(w_df, *['수위'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(w_df, *['수위'], **{})
# chart

# %% [markdown]
# # 데이터 전처리

# %%
features = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

# %%
test_df1 = df1[features].values
test_df2 = df2[features].values
test_df3 = df3[features].values

# %%
test_wdf = w_df[["수위"]].values

# %%
print(test_df1.shape)
print(test_df2.shape)
print(test_df3.shape)
print(test_wdf.shape)
# Out:
# (17520, 5)
# (17520, 5)
# (17520, 5)
# (17485, 1)

# %% [markdown]
# ## 정규화

# %%
# 정규화
scaler = MinMaxScaler()

# 상류 하천 데이터 정규화
test_df1_z = scaler.fit_transform(test_df1)
test_df2_z = scaler.fit_transform(test_df2)
test_df3_z = scaler.fit_transform(test_df3)
test_wdf_z = scaler.fit_transform(test_wdf)

# %%
test_df1_z
# Out:
# array([[0.26987061, 0.69288703, 0.16666667, 0.        , 0.76744186],
#        [0.23844732, 0.76596932, 0.10784314, 0.        , 0.87209302],
#        [0.24214418, 0.83542538, 0.1372549 , 0.        , 0.86046512],
#        ...,
#        [0.30314233, 0.        , 0.00980392, 0.        , 0.94186047],
#        [0.29759704, 0.        , 0.00980392, 0.        , 0.94186047],
#        [0.2754159 , 0.19414226, 0.06862745, 0.        , 0.97674419]])

# %%
test_wdf_z
# Out:
# array([[0.05668016],
#        [0.05668016],
#        [0.05668016],
#        ...,
#        [0.05668016],
#        [0.05668016],
#        [0.05668016]])

# %%
print(test_df1_z.shape)
print(test_df2_z.shape)
print(test_df3_z.shape)
print(test_wdf_z.shape)
# Out:
# (17520, 5)
# (17520, 5)
# (17520, 5)
# (17485, 1)

# %% [markdown]
# ## 차원변환

# %% [markdown]
# - 강진면

# %%
time_steps = 36

new_data = []

for i in range(len(test_df1_z) - time_steps + 1):
    batch = test_df1_z[i:i+time_steps]
    new_data.append(batch)

test_df1_re = np.array(new_data)

# %%
test_df1_re

# %%
test_df1_re.shape
# Out:
# (17485, 36, 5)

# %% [markdown]
# - 신덕

# %%
new_data = []

for i in range(len(test_df2_z) - time_steps + 1):
    batch = test_df2_z[i:i+time_steps]
    new_data.append(batch)

test_df2_re = np.array(new_data)

# %%
test_df2_re.shape
# Out:
# (17485, 36, 5)

# %% [markdown]
# - 곡성

# %%
new_data = []

for i in range(len(test_df3_z) - time_steps + 1):
    batch = test_df3_z[i:i+time_steps]
    new_data.append(batch)

test_df3_re = np.array(new_data)

# %%
test_df3_re.shape
# Out:
# (17485, 36, 5)

# %%
print("NumPy array dtype:", test_df2_re.dtype)
# Out:
# NumPy array dtype: float64

# %% [markdown]
# - 수위

# %%
test_wdf_z.shape  # 위에서 변경함
# Out:
# (17485, 1)

# %% [markdown]
# # 모델

# %% [markdown]
# - CNN_Lstm

# %%
num_top = 3  # 상류 하천의 수
time_steps = 36
# 모델의 입력 레이어 정의
input_layers = []
input_shape = (time_steps, 5)
for i in range(num_top):
    input_layer = Input(shape=input_shape, name=f'aws_{i+1}')
    input_layers.append(input_layer)

# CNN 레이어 정의
cnn_layers = []
for i in range(num_top):
    cnn_layer = Conv1D(filters=64, kernel_size=3, activation='relu')(input_layers[i])
    cnn_layer = MaxPooling1D(pool_size=2)(cnn_layer)
    cnn_layer = Flatten()(cnn_layer)
    cnn_layers.append(cnn_layer)

concatenated_outputs = Concatenate()(cnn_layers)
lstm_input = tf.keras.layers.Reshape((num_top, -1))(concatenated_outputs)  # LSTM에 입력하기 위해 차원 재구성


lstm_layer = LSTM(32, activation='relu')(lstm_input)

output_layer = Dense(1, activation='linear', name='water')(lstm_layer)

# %%
# 모델 컴파일
model = Model(inputs=input_layers, outputs=output_layer)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  aws_1 (InputLayer)          [(None, 36, 5)]              0         []
#
#  aws_2 (InputLayer)          [(None, 36, 5)]              0         []
#
#  aws_3 (InputLayer)          [(None, 36, 5)]              0         []
#
#  conv1d (Conv1D)             (None, 34, 64)               1024      ['aws_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 34, 64)               1024      ['aws_2[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 34, 64)               1024      ['aws_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 17, 64)               0         ['conv1d[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 17, 64)               0         ['conv1d_1[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 17, 64)               0         ['conv1d_2[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 1088)                 0         ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)         (None, 1088)                 0         ['max_pooling1d_1[0][0]']
#
#  flatten_2 (Flatten)         (None, 1088)                 0         ['max_pooling1d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 3264)                 0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]',
#                                                                      'flatten_2[0][0]']
#
#  reshape (Reshape)           (None, 3, 1088)              0         ['concatenate[0][0]']
#
#  lstm (LSTM)                 (None, 32)                   143488    ['reshape[0][0]']
#
#  water (Dense)               (None, 1)                    33        ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 146593 (572.63 KB)
# Trainable params: 146593 (572.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # 학습

# %%
model.fit([test_df1_re, test_df2_re, test_df3_re], test_wdf_z, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 547/547 [==============================] - 10s 14ms/step - loss: 0.0032 - mae: 0.0366
# Epoch 2/100
# 547/547 [==============================] - 7s 12ms/step - loss: 0.0021 - mae: 0.0318
# Epoch 3/100
# 547/547 [==============================] - 7s 14ms/step - loss: 0.0019 - mae: 0.0303
# Epoch 4/100
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0016 - mae: 0.0290
# Epoch 5/100
# 547/547 [==============================] - 7s 14ms/step - loss: 0.0016 - mae: 0.0286
# Epoch 6/100
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0014 - mae: 0.0269
# Epoch 7/100
# 547/547 [==============================] - 8s 14ms/step - loss: 0.0012 - mae: 0.0262
# Epoch 8/100
# 547/547 [==============================] - 6s 11ms/step - loss: 0.0012 - mae: 0.0257
# Epoch 9/100
# 547/547 [==============================] - 8s 14ms/step - loss: 0.0011 - mae: 0.0245
# Epoch 10/100
# 547/547 [==============================] - 7s 13ms/step - loss: 9.9683e-04 - mae: 0.0237
# Epoch 11/100
# 547/547 [==============================] - 7s 14ms/step - loss: 9.1745e-04 - mae: 0.0229
# Epoch 12/100
# 547/547 [==============================] - 7s 13ms/step - loss: 8.7644e-04 - mae: 0.0223
# Epoch 13/100
# 547/547 [==============================] - 6s 12ms/step - loss: 8.5027e-04 - mae: 0.0218
# Epoch 14/100
# 547/547 [==============================] - 7s 14ms/step - loss: 7.2389e-04 - mae: 0.0204
# Epoch 15/100
# 547/547 [==============================] - 6s 11ms/step - loss: 6.9181e-04 - mae: 0.0199
# Epoch 16/100
# 547/547 [==============================] - 8s 14ms/step - loss: 6.2175e-04 - mae: 0.0189
# Epoch 17/100
# 547/547 [==============================] - 7s 14ms/step - loss: 5.8609e-04 - mae: 0.0184
# Epoch 18/100
# 547/547 [==============================] - 8s 14ms/step - loss: 5.3311e-04 - mae: 0.0175
# Epoch 19/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.9431e-04 - mae: 0.0169
# Epoch 20/100
# 547/547 [==============================] - 7s 14ms/step - loss: 5.0048e-04 - mae: 0.0167
# Epoch 21/100
# 547/547 [==============================] - 7s 13ms/step - loss: 4.2060e-04 - mae: 0.0155
# Epoch 22/100
# 547/547 [==============================] - 7s 12ms/step - loss: 3.9020e-04 - mae: 0.0149
# Epoch 23/100
# 547/547 [==============================] - 7s 14ms/step - loss: 3.8560e-04 - mae: 0.0148
# Epoch 24/100
# 547/547 [==============================] - 6s 12ms/step - loss: 3.3981e-04 - mae: 0.0139
# Epoch 25/100
# 547/547 [==============================] - 7s 14ms/step - loss: 3.3759e-04 - mae: 0.0137
# Epoch 26/100
# 547/547 [==============================] - 6s 12ms/step - loss: 3.1435e-04 - mae: 0.0133
# Epoch 27/100
# 547/547 [==============================] - 7s 14ms/step - loss: 2.7381e-04 - mae: 0.0125
# Epoch 28/100
# 547/547 [==============================] - 6s 11ms/step - loss: 2.6259e-04 - mae: 0.0122
# Epoch 29/100
# 547/547 [==============================] - 7s 13ms/step - loss: 2.5827e-04 - mae: 0.0120
# Epoch 30/100
# 547/547 [==============================] - 6s 11ms/step - loss: 2.2078e-04 - mae: 0.0112
# Epoch 31/100
# 547/547 [==============================] - 7s 13ms/step - loss: 2.1568e-04 - mae: 0.0110
# Epoch 32/100
# 547/547 [==============================] - 6s 11ms/step - loss: 2.0958e-04 - mae: 0.0109
# Epoch 33/100
# 547/547 [==============================] - 7s 14ms/step - loss: 2.0048e-04 - mae: 0.0105
# Epoch 34/100
# 547/547 [==============================] - 7s 12ms/step - loss: 1.8024e-04 - mae: 0.0101
# Epoch 35/100
# 547/547 [==============================] - 7s 13ms/step - loss: 1.7656e-04 - mae: 0.0099
# Epoch 36/100
# 547/547 [==============================] - 7s 14ms/step - loss: 1.6144e-04 - mae: 0.0096
# Epoch 37/100
# 547/547 [==============================] - 6s 11ms/step - loss: 1.5743e-04 - mae: 0.0095
# Epoch 38/100
# 547/547 [==============================] - 7s 14ms/step - loss: 1.6173e-04 - mae: 0.0094
# Epoch 39/100
# 547/547 [==============================] - 6s 11ms/step - loss: 1.3731e-04 - mae: 0.0088
# Epoch 40/100
# 547/547 [==============================] - 7s 14ms/step - loss: 1.1709e-04 - mae: 0.0081
# Epoch 41/100
# 547/547 [==============================] - 6s 11ms/step - loss: 1.3763e-04 - mae: 0.0088
# Epoch 42/100
# 547/547 [==============================] - 8s 14ms/step - loss: 1.4580e-04 - mae: 0.0087
# Epoch 43/100
# 547/547 [==============================] - 6s 11ms/step - loss: 1.2272e-04 - mae: 0.0083
# Epoch 44/100
# 547/547 [==============================] - 8s 14ms/step - loss: 1.1757e-04 - mae: 0.0080
# Epoch 45/100
# 547/547 [==============================] - 6s 11ms/step - loss: 1.2215e-04 - mae: 0.0082
# Epoch 46/100
# 547/547 [==============================] - 7s 14ms/step - loss: 1.0624e-04 - mae: 0.0077
# Epoch 47/100
# 547/547 [==============================] - 7s 12ms/step - loss: 9.6792e-05 - mae: 0.0074
# Epoch 48/100
# 547/547 [==============================] - 7s 13ms/step - loss: 9.9122e-05 - mae: 0.0074
# Epoch 49/100
# 547/547 [==============================] - 7s 14ms/step - loss: 9.2964e-05 - mae: 0.0072
# Epoch 50/100
# 547/547 [==============================] - 6s 12ms/step - loss: 8.8916e-05 - mae: 0.0071
# Epoch 51/100
# 547/547 [==============================] - 8s 14ms/step - loss: 1.0068e-04 - mae: 0.0074
# Epoch 52/100
# 547/547 [==============================] - 6s 12ms/step - loss: 9.4359e-05 - mae: 0.0072
# Epoch 53/100
# 547/547 [==============================] - 8s 14ms/step - loss: 8.4110e-05 - mae: 0.0067
# Epoch 54/100
# 547/547 [==============================] - 6s 12ms/step - loss: 7.4295e-05 - mae: 0.0065
# Epoch 55/100
# 547/547 [==============================] - 7s 14ms/step - loss: 8.4053e-05 - mae: 0.0067
# Epoch 56/100
# 547/547 [==============================] - 6s 11ms/step - loss: 8.7430e-05 - mae: 0.0067
# Epoch 57/100
# 547/547 [==============================] - 7s 14ms/step - loss: 1.0015e-04 - mae: 0.0071
# Epoch 58/100
# 547/547 [==============================] - 6s 12ms/step - loss: 6.5564e-05 - mae: 0.0060
# Epoch 59/100
# 547/547 [==============================] - 8s 14ms/step - loss: 8.5072e-05 - mae: 0.0067
# Epoch 60/100
# 547/547 [==============================] - 7s 13ms/step - loss: 6.8434e-05 - mae: 0.0062
# Epoch 61/100
# 547/547 [==============================] - 7s 12ms/step - loss: 6.9742e-05 - mae: 0.0062
# Epoch 62/100
# 547/547 [==============================] - 7s 14ms/step - loss: 8.2764e-05 - mae: 0.0066
# Epoch 63/100
# 547/547 [==============================] - 6s 11ms/step - loss: 6.9302e-05 - mae: 0.0061
# Epoch 64/100
# 547/547 [==============================] - 8s 14ms/step - loss: 7.3079e-05 - mae: 0.0062
# Epoch 65/100
# 547/547 [==============================] - 6s 12ms/step - loss: 7.3065e-05 - mae: 0.0062
# Epoch 66/100
# 547/547 [==============================] - 8s 14ms/step - loss: 5.8817e-05 - mae: 0.0057
# Epoch 67/100
# 547/547 [==============================] - 6s 11ms/step - loss: 5.8405e-05 - mae: 0.0057
# Epoch 68/100
# 547/547 [==============================] - 7s 14ms/step - loss: 5.7442e-05 - mae: 0.0056
# Epoch 69/100
# 547/547 [==============================] - 6s 11ms/step - loss: 6.9966e-05 - mae: 0.0061
# Epoch 70/100
# 547/547 [==============================] - 7s 14ms/step - loss: 7.4528e-05 - mae: 0.0062
# Epoch 71/100
# 547/547 [==============================] - 7s 12ms/step - loss: 6.1982e-05 - mae: 0.0057
# Epoch 72/100
# 547/547 [==============================] - 7s 13ms/step - loss: 5.6512e-05 - mae: 0.0054
# Epoch 73/100
# 547/547 [==============================] - 7s 13ms/step - loss: 6.2580e-05 - mae: 0.0057
# Epoch 74/100
# 547/547 [==============================] - 7s 12ms/step - loss: 6.6485e-05 - mae: 0.0058
# Epoch 75/100
# 547/547 [==============================] - 7s 13ms/step - loss: 5.6479e-05 - mae: 0.0055
# Epoch 76/100
# 547/547 [==============================] - 6s 11ms/step - loss: 5.0165e-05 - mae: 0.0052
# Epoch 77/100
# 547/547 [==============================] - 7s 14ms/step - loss: 4.2327e-05 - mae: 0.0050
# Epoch 78/100
# 547/547 [==============================] - 6s 12ms/step - loss: 5.3549e-05 - mae: 0.0053
# Epoch 79/100
# 547/547 [==============================] - 7s 14ms/step - loss: 8.2185e-05 - mae: 0.0064
# Epoch 80/100
# 547/547 [==============================] - 6s 11ms/step - loss: 6.2717e-05 - mae: 0.0056
# Epoch 81/100
# 547/547 [==============================] - 8s 14ms/step - loss: 5.3741e-05 - mae: 0.0052
# Epoch 82/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.5831e-05 - mae: 0.0050
# Epoch 83/100
# 547/547 [==============================] - 7s 14ms/step - loss: 4.4097e-05 - mae: 0.0049
# Epoch 84/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.7815e-05 - mae: 0.0051
# Epoch 85/100
# 547/547 [==============================] - 7s 14ms/step - loss: 4.8316e-05 - mae: 0.0051
# Epoch 86/100
# 547/547 [==============================] - 7s 12ms/step - loss: 4.6430e-05 - mae: 0.0050
# Epoch 87/100
# 547/547 [==============================] - 7s 13ms/step - loss: 6.3840e-05 - mae: 0.0056
# Epoch 88/100
# 547/547 [==============================] - 7s 13ms/step - loss: 4.5206e-05 - mae: 0.0049
# Epoch 89/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.7581e-05 - mae: 0.0050
# Epoch 90/100
# 547/547 [==============================] - 7s 13ms/step - loss: 5.2488e-05 - mae: 0.0052
# Epoch 91/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.5251e-05 - mae: 0.0049
# Epoch 92/100
# 547/547 [==============================] - 7s 14ms/step - loss: 4.6295e-05 - mae: 0.0049
# Epoch 93/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.2251e-05 - mae: 0.0047
# Epoch 94/100
# 547/547 [==============================] - 7s 14ms/step - loss: 4.7480e-05 - mae: 0.0049
# Epoch 95/100
# 547/547 [==============================] - 6s 11ms/step - loss: 5.4450e-05 - mae: 0.0052
# Epoch 96/100
# 547/547 [==============================] - 7s 14ms/step - loss: 4.3743e-05 - mae: 0.0048
# Epoch 97/100
# 547/547 [==============================] - 6s 11ms/step - loss: 4.0965e-05 - mae: 0.0046
# Epoch 98/100
# 547/547 [==============================] - 7s 13ms/step - loss: 3.4798e-05 - mae: 0.0043
# Epoch 99/100
# 547/547 [==============================] - 6s 11ms/step - loss: 3.6819e-05 - mae: 0.0044
# Epoch 100/100
# 547/547 [==============================] - 7s 14ms/step - loss: 5.8710e-05 - mae: 0.0055

# %% [markdown]
# # 결과

# %%
predictions = model.predict([test_df1_re, test_df2_re, test_df3_re])
# Out:
# 547/547 [==============================] - 2s 4ms/step

# %%
predictions_scale = scaler.inverse_transform(predictions)

# %%
predictions_scale.shape
# Out:
# (17485, 1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(predictions_scale, label='Predicted', color = 'b', alpha=0.7)
plt.plot(test_wdf, label='Actual', color = 'y', alpha=0.7)

plt.xlabel('Time Step')
plt.ylabel('Water Level')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()

# %%
predictions_scale[:10]
# Out:
# array([[0.6009036 ],
#        [0.58912534],
#        [0.5981009 ],
#        [0.5998342 ],
#        [0.59689546],
#        [0.58833826],
#        [0.57717234],
#        [0.5810191 ],
#        [0.5962953 ],
#        [0.58392113]], dtype=float32)

# %% [markdown]
# - 모델저장

# %%
model.save("model_test(36)_cnn.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from pickle import dump

dump(scaler, open('./36_cnn_scaler.pkl', 'wb'))

# %% [markdown]
# # 모델 테스트

# %% [markdown]
# - 걍다시 ㄱ

# %%
t1 = pd.read_csv('11111.csv')

# %%
t2 = pd.read_csv('22222.csv')

# %%
t3 = pd.read_csv('33333.csv')

# %%
tw = pd.read_csv('test수위48.csv')

# %%
test_w = tw[["수위"]].values

# %%
from keras.models import load_model

model_filename = 'model_test(36)_cnn.h5'

loaded_model = load_model(model_filename)

# %%
from pickle import load

load_minmax_scaler = load(open('36_cnn_scaler.pkl', 'rb'))

# %% [markdown]
# ## 데이터 전처리

# %%
features = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

# %%
test_t1 = t1[features].values
test_t2 = t2[features].values
test_t3 = t3[features].values

# %% [markdown]
# ### 정규화

# %%
# 정규화
scaler = MinMaxScaler()

# 상류 하천 데이터 정규화
test_df1_z = scaler.fit_transform(test_t1)
test_df2_z = scaler.fit_transform(test_t2)
test_df3_z = scaler.fit_transform(test_t3)

# %%
time_steps = 48

new_data = []

for i in range(len(test_df1_z) - time_steps + 1):
    batch = test_df1_z[i:i+time_steps]
    new_data.append(batch)

test_df1_re = np.array(new_data)

# %%
test_df1_re.shape
# Out:
# (25, 48, 5)

# %%
new_data = []

for i in range(len(test_df2_z) - time_steps + 1):
    batch = test_df2_z[i:i+time_steps]
    new_data.append(batch)

test_df2_re = np.array(new_data)

# %%
new_data = []

for i in range(len(test_df3_z) - time_steps + 1):
    batch = test_df3_z[i:i+time_steps]
    new_data.append(batch)

test_df3_re = np.array(new_data)

# %% [markdown]
# ### 결과

# %%
predictions = loaded_model.predict([test_df1_re, test_df2_re, test_df3_re])
# Out:
# 1/1 [==============================] - 0s 252ms/step

# %%
predictions

# %%
predictions_scaler = load_minmax_scaler.inverse_transform(predictions)

# %%
predictions_scaler
# Out:
# array([[0.47555807],
#        [0.5576896 ],
#        [0.5862413 ],
#        [0.5750251 ],
#        [0.5809162 ],
#        [0.58277726],
#        [0.631615  ],
#        [0.63849574],
#        [0.697653  ],
#        [0.6972739 ],
#        [0.6980707 ],
#        [0.6972687 ],
#        [0.7007477 ],
#        [0.7203783 ],
#        [0.7078872 ],
#        [0.7281587 ],
#        [0.7202893 ],
#        [0.6933413 ],
#        [0.6567633 ],
#        [0.5201135 ],
#        [0.5412229 ],
#        [0.58299375],
#        [0.6062502 ],
#        [0.5547263 ],
#        [0.55971223]], dtype=float32)

# %%
predictions_scaler.shape
# Out:
# (25, 1)

# %%
test_w
# Out:
# array([[0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.66]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(predictions_scaler, label='Predicted', color = 'b', alpha=0.7)
plt.plot(test_w, label='Actual', color = 'y', alpha=0.7)

plt.xlabel('Time Step')
plt.ylabel('Water Level')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()

# %% [markdown]
# ## 3시간 테스트
# -> 27개의데이터

# %%
t1 = pd.read_csv('test36-1.csv')

# %%
t2 = pd.read_csv('test36-2.csv')

# %%
t3 = pd.read_csv('test36-3.csv')

# %%
features = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

# %%
t3
# Out:
#      지점 지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  현지기압(hPa)  \
# 0   768  곡성  2023-08-16 00:00    25.2      0.0      0.0      0.0      993.8
# 1   768  곡성  2023-08-16 01:00    24.7      0.0      0.1      0.0      993.6
# 2   768  곡성  2023-08-16 02:00    25.1      0.0      0.0      0.0      993.4
# 3   768  곡성  2023-08-16 03:00    25.1    215.0      0.5      0.0      993.5
# 4   768  곡성  2023-08-16 04:00    24.9      0.0      0.4      0.0      993.2
# 5   768  곡성  2023-08-16 05:00    25.0      0.0      0.0      0.0      993.2
# 6   768  곡성  2023-08-16 06:00    24.7      0.0      0.0      0.0      993.5
# 7   768  곡성  2023-08-16 07:00    25.2      0.0      0.0      0.0      994.0
# 8   768  곡성  2023-08-16 08:00    26.3      0.0      0.3      0.0      994.3
# 9   768  곡성  2023-08-16 09:00    26.4    185.8      1.8      0.0      994.4
# 10  768  곡성  2023-08-16 10:00    28.3    163.0      1.6      0.0      994.2
# 11  768  곡성  2023-08-16 11:00    30.2      0.0      0.0      0.0      993.8
# 12  768  곡성  2023-08-16 12:00    31.5     38.0      1.3      0.0      993.2
# 13  768  곡성  2023-08-16 13:00    30.5      0.0      0.0      0.0      993.0
# 14  768  곡성  2023-08-16 14:00    31.8    187.7      2.0      0.0      992.6
# 15  768  곡성  2023-08-16 15:00    32.4    210.8      2.4      0.0      992.4
# 16  768  곡성  2023-08-16 16:00    32.0    257.5      1.3      0.0      992.1
# 17  768  곡성  2023-08-16 17:00    32.0    247.5      0.9      0.0      992.0
# 18  768  곡성  2023-08-16 18:00    30.4    218.4      0.8      0.0      992.0
# 19  768  곡성  2023-08-16 19:00    28.1    280.5      0.5      0.0      992.2
# 20  768  곡성  2023-08-16 20:00    27.6    235.4      1.4      0.0      992.7
# 21  768  곡성  2023-08-16 21:00    26.8      0.0      0.3      0.0      993.6
# 22  768  곡성  2023-08-16 22:00    26.3     31.3      1.4      0.0      994.3
# 23  768  곡성  2023-08-16 23:00    25.3    309.8      0.9      0.0      994.3
# 24  768  곡성  2023-08-17 00:00    24.2      0.0      0.4      0.0      994.4
# 25  768  곡성  2023-08-17 01:00    23.7      0.0      0.0      0.0      994.2
# 26  768  곡성  2023-08-17 02:00    23.4      0.0      0.4      0.0      994.0
# 27  768  곡성  2023-08-17 03:00    22.8      0.0      0.0      0.0      993.7
# 28  768  곡성  2023-08-17 04:00    22.3      0.0      0.0      0.0      993.7
# 29  768  곡성  2023-08-17 05:00    22.1      0.0      0.0      0.0      993.4
# 30  768  곡성  2023-08-17 06:00    22.1      0.0      0.0      0.0      993.6
# 31  768  곡성  2023-08-17 07:00    23.5      0.0      0.0      0.0      994.1
# 32  768  곡성  2023-08-17 08:00    25.3      0.0      0.0      0.0      994.6
# 33  768  곡성  2023-08-17 09:00    26.4      0.0      0.0      0.0      995.1
# 34  768  곡성  2023-08-17 10:00    28.2      0.0      0.4      0.0      994.9
# 35  768  곡성  2023-08-17 11:00    29.8    106.7      1.1      0.0      994.5
# 36  768  곡성  2023-08-17 12:00    30.2     20.8      2.1      0.0      994.1
# 37  768  곡성  2023-08-17 13:00    31.1     47.1      1.3      0.0      993.8
#
#     해면기압(hPa)  습도(%)
# 0      1005.2   92.0
# 1      1004.9   94.0
# 2      1004.8   93.0
# 3      1004.9   91.0
# 4      1004.6   93.0
# 5      1004.6   92.0
# 6      1004.8   93.0
# 7      1005.4   90.0
# 8      1005.6   85.0
# 9      1005.7   86.0
# 10     1005.4   76.0
# 11     1005.0   73.0
# 12     1004.3   69.0
# 13     1004.1   70.0
# 14     1003.7   61.0
# 15     1003.5   56.0
# 16     1003.2   57.0
# 17     1003.1   57.0
# 18     1003.1   69.0
# 19     1003.4   78.0
# 20     1003.9   77.0
# 21     1004.9   81.0
# 22     1005.6   82.0
# 23     1005.7   88.0
# 24     1005.7   93.0
# 25     1005.6   94.0
# 26     1005.4   95.0
# 27     1005.1   96.0
# 28     1005.1   97.0
# 29     1004.9   98.0
# 30     1005.1   98.0
# 31     1005.5   95.0
# 32     1006.0   88.0
# 33     1006.4   85.0
# 34     1006.1   76.0
# 35     1005.7   69.0
# 36     1005.3   71.0
# 37     1004.9   68.0

# %%
test_t1 = t1[features].values
test_t2 = t2[features].values
test_t3 = t3[features].values

# %%
# 정규화
scaler = MinMaxScaler()

# 상류 하천 데이터 정규화
test_df1_z = scaler.fit_transform(test_t1)
test_df2_z = scaler.fit_transform(test_t2)
test_df3_z = scaler.fit_transform(test_t3)

# %%
time_steps = 36

new_data = []

for i in range(len(test_df1_z) - time_steps + 1):
    batch = test_df1_z[i:i+time_steps]
    new_data.append(batch)

test_df1_re = np.array(new_data)

# %%
new_data = []

for i in range(len(test_df2_z) - time_steps + 1):
    batch = test_df2_z[i:i+time_steps]
    new_data.append(batch)

test_df2_re = np.array(new_data)

# %%
new_data = []

for i in range(len(test_df3_z) - time_steps + 1):
    batch = test_df3_z[i:i+time_steps]
    new_data.append(batch)

test_df3_re = np.array(new_data)

# %%
test_df3_re.shape
# Out:
# (3, 36, 5)

# %%
test_df3_re

# %%
predictions_t3 = loaded_model.predict([test_df1_re, test_df2_re, test_df3_re])
# Out:
# 1/1 [==============================] - 0s 249ms/step

# %%
predictions_t3
# Out:
# array([[0.02407827],
#        [0.05264486],
#        [0.06560145]], dtype=float32)

# %%
predictions_scaler_3 = load_minmax_scaler.inverse_transform(predictions_t3)

# %%
predictions_scaler_3
# Out:
# array([[0.5194734 ],
#        [0.5900328 ],
#        [0.62203556]], dtype=float32)

# %%
tw1 = pd.read_csv('test수위36-1.csv')

# %%
test_w = tw1[["수위"]].values

# %%
test_w
# Out:
# array([[0.68],
#        [0.67],
#        [0.67]])

# %%
# RMSE
rmse = np.sqrt(((predictions_scaler_3 - test_w) ** 2).mean())

# MAE
mae = np.abs(predictions_scaler_3 - test_w).mean()

print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# RMSE: 0.10718229865566845
# MAE: 0.09615274906158451

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(predictions_scaler_3, label='Predicted', color = 'b', alpha=0.7)
plt.plot(test_w, label='Actual', color = 'y', alpha=0.7)

plt.xlabel('Time Step')
plt.ylabel('Water Level')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()

# %%
predictions_scaler_3
# Out:
# array([[1.0374911 ],
#        [0.90322655],
#        [1.0528685 ]], dtype=float32)

# %%
# 데이터 포인트 레이블
data_labels = ['15:00', '16:00', '17:00']

# 그래프 데이터
x = np.arange(len(data_labels))
width = 0.35

# 예측값과 실제값 막대 그래프 생성
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, predictions_scaler_3.flatten(), width, label='Predictions')
rects2 = ax.bar(x + width/2, test_w.flatten(), width, label='Actual')

# 레이블과 범례 설정
ax.set_xlabel('Time')
ax.set_ylabel('Water')
ax.set_title('Predicted vs Actual')
ax.set_xticks(x)
ax.set_xticklabels(data_labels)
ax.legend()

ax.legend(loc='lower right')

# 막대 위에 값 표시
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3),
                    textcoords="offset points", ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.tight_layout()
plt.show()
