# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense, concatenate
from sklearn.model_selection import train_test_split
from keras.models import load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.layers import Concatenate

# %% [markdown]
# # 데이터로드

# %%
df1 = pd.read_csv('21-01-01~22-12-31강진면.csv')

# %%
df2 = pd.read_csv('21-01-01~22-12-31신덕.csv')

# %%
df3 = pd.read_csv('21-01-01~22-12-31곡성.csv')

# %%
w_df = pd.read_csv('가탄교수위.csv')

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
print(w_df.shape)
# Out:
# (17520, 10)
# (17520, 10)
# (17520, 10)
# (17523, 2)

# %%
w_df = w_df.loc[62:]

# %%
w_df
# Out:
#                      일시   수위
# 62     2021-01-03 15:00  0.6
# 63     2021-01-03 16:00  0.6
# 64     2021-01-03 17:00  0.6
# 65     2021-01-03 18:00  0.6
# 66     2021-01-03 19:00  0.6
# ...                 ...  ...
# 17518  2022-12-31 23:00  0.6
# 17519  2022-12-31 24:00  0.6
# 17520  2023-01-01 01:00  0.6
# 17521  2023-01-01 02:00  0.6
# 17522  2023-01-01 03:00  0.6
#
# [17461 rows x 2 columns]

# %% [markdown]
# # 데이터 전처리

# %%
features = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

# %%
test_df1 = df1[features].values
test_df2 = df2[features].values
test_df3 = df3[features].values

# %%
test_wdf = w_df[["수위"]].values

# %%
print(test_df1.shape)
print(test_df2.shape)
print(test_df3.shape)
print(test_wdf.shape)
# Out:
# (17520, 5)
# (17520, 5)
# (17520, 5)
# (17461, 1)

# %% [markdown]
# ## 정규화

# %%
# 정규화
scaler = MinMaxScaler()

# 상류 하천 데이터 정규화
test_df1_z = scaler.fit_transform(test_df1)
test_df2_z = scaler.fit_transform(test_df2)
test_df3_z = scaler.fit_transform(test_df3)
test_wdf_z = scaler.fit_transform(test_wdf)

# %%
test_df1_z
# Out:
# array([[0.26987061, 0.69288703, 0.16666667, 0.        , 0.76744186],
#        [0.23844732, 0.76596932, 0.10784314, 0.        , 0.87209302],
#        [0.24214418, 0.83542538, 0.1372549 , 0.        , 0.86046512],
#        ...,
#        [0.30314233, 0.        , 0.00980392, 0.        , 0.94186047],
#        [0.29759704, 0.        , 0.00980392, 0.        , 0.94186047],
#        [0.2754159 , 0.19414226, 0.06862745, 0.        , 0.97674419]])

# %%
test_wdf_z
# Out:
# array([[0.05668016],
#        [0.05668016],
#        [0.05668016],
#        ...,
#        [0.05668016],
#        [0.05668016],
#        [0.05668016]])

# %%
print(test_df1_z.shape)
print(test_df2_z.shape)
print(test_df3_z.shape)
print(test_wdf_z.shape)
# Out:
# (17520, 5)
# (17520, 5)
# (17520, 5)
# (17461, 1)

# %% [markdown]
# ## 차원변환

# %% [markdown]
# - 강진면

# %%
time_steps = 60

new_data = []

for i in range(len(test_df1_z) - time_steps + 1):
    batch = test_df1_z[i:i+time_steps]
    new_data.append(batch)

test_df1_re = np.array(new_data)

# %%
test_df1_re
# Out:
# array([[[0.26987061, 0.69288703, 0.16666667, 0.        , 0.76744186],
#         [0.23844732, 0.76596932, 0.10784314, 0.        , 0.87209302],
#         [0.24214418, 0.83542538, 0.1372549 , 0.        , 0.86046512],
#         ...,
#         [0.28465804, 0.71910739, 0.23529412, 0.        , 0.51162791],
#         [0.33086876, 0.76290098, 0.37254902, 0.        , 0.41860465],
#         [0.35674677, 0.75564854, 0.44117647, 0.        , 0.43023256]],
#
#        [[0.23844732, 0.76596932, 0.10784314, 0.        , 0.87209302],
#         [0.24214418, 0.83542538, 0.1372549 , 0.        , 0.86046512],
#         [0.23475046, 0.        , 0.        , 0.        , 0.91860465],
#         ...,
#         [0.33086876, 0.76290098, 0.37254902, 0.        , 0.41860465],
#         [0.35674677, 0.75564854, 0.44117647, 0.        , 0.43023256],
#         [0.36968577, 0.75983264, 0.43137255, 0.        , 0.40697674]],
#
#        [[0.24214418, 0.83542538, 0.1372549 , 0.        , 0.86046512],
#         [0.23475046, 0.        , 0.        , 0.        , 0.91860465],
#         [0.21256932, 0.        , 0.01960784, 0.        , 0.93023256],
#         ...,
#         [0.35674677, 0.75564854, 0.44117647, 0.        , 0.43023256],
#         [0.36968577, 0.75983264, 0.43137255, 0.        , 0.40697674],
#         [0.39926063, 0.72942817, 0.2745098 , 0.        , 0.38372093]],
#
#        ...,
#
#        [[0.27171904, 0.        , 0.        , 0.        , 0.96511628],
#         [0.34565619, 0.6376569 , 0.07843137, 0.        , 0.75581395],
#         [0.39556377, 0.72050209, 0.24509804, 0.        , 0.47674419],
#         ...,
#         [0.33456562, 0.        , 0.00980392, 0.        , 0.84883721],
#         [0.32532348, 0.        , 0.02941176, 0.        , 0.86046512],
#         [0.30314233, 0.        , 0.00980392, 0.        , 0.94186047]],
#
#        [[0.34565619, 0.6376569 , 0.07843137, 0.        , 0.75581395],
#         [0.39556377, 0.72050209, 0.24509804, 0.        , 0.47674419],
#         [0.39556377, 0.63682008, 0.15686275, 0.        , 0.48837209],
#         ...,
#         [0.32532348, 0.        , 0.02941176, 0.        , 0.86046512],
#         [0.30314233, 0.        , 0.00980392, 0.        , 0.94186047],
#         [0.29759704, 0.        , 0.00980392, 0.        , 0.94186047]],
#
#        [[0.39556377, 0.72050209, 0.24509804, 0.        , 0.47674419],
#         [0.39556377, 0.63682008, 0.15686275, 0.        , 0.48837209],
#         [0.4232902 , 0.69344491, 0.16666667, 0.        , 0.48837209],
#         ...,
#         [0.30314233, 0.        , 0.00980392, 0.        , 0.94186047],
#         [0.29759704, 0.        , 0.00980392, 0.        , 0.94186047],
#         [0.2754159 , 0.19414226, 0.06862745, 0.        , 0.97674419]]])

# %%
test_df1_re.shape
# Out:
# (17461, 60, 5)

# %% [markdown]
# - 신덕

# %%
new_data = []

for i in range(len(test_df2_z) - time_steps + 1):
    batch = test_df2_z[i:i+time_steps]
    new_data.append(batch)

test_df2_re = np.array(new_data)

# %%
test_df2_re.shape
# Out:
# (17461, 60, 5)

# %% [markdown]
# - 곡성

# %%
new_data = []

for i in range(len(test_df3_z) - time_steps + 1):
    batch = test_df3_z[i:i+time_steps]
    new_data.append(batch)

test_df3_re = np.array(new_data)

# %%
test_df3_re.shape
# Out:
# (17461, 60, 5)

# %%
print("NumPy array dtype:", test_df2_re.dtype)
# Out:
# NumPy array dtype: float64

# %% [markdown]
# - 수위

# %%
test_wdf_z.shape  # 위에서 변경함
# Out:
# (17461, 1)

# %% [markdown]
# # 모델

# %% [markdown]
# - CNN_Lstm

# %%
num_top = 3  # 상류 하천의 수
time_steps = 60
# 모델의 입력 레이어 정의
input_layers = []
input_shape = (time_steps, 5)
for i in range(num_top):
    input_layer = Input(shape=input_shape, name=f'aws_{i+1}')
    input_layers.append(input_layer)

# CNN 레이어 정의
cnn_layers = []
for i in range(num_top):
    cnn_layer = Conv1D(filters=64, kernel_size=3, activation='relu')(input_layers[i])
    cnn_layer = MaxPooling1D(pool_size=2)(cnn_layer)
    cnn_layer = Flatten()(cnn_layer)
    cnn_layers.append(cnn_layer)

concatenated_outputs = Concatenate()(cnn_layers)
lstm_input = tf.keras.layers.Reshape((num_top, -1))(concatenated_outputs)  # LSTM에 입력하기 위해 차원 재구성


lstm_layer = LSTM(32, activation='relu')(lstm_input)

output_layer = Dense(1, activation='linear', name='water')(lstm_layer)

# %%
# 모델 컴파일
model = Model(inputs=input_layers, outputs=output_layer)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  aws_1 (InputLayer)          [(None, 60, 5)]              0         []
#
#  aws_2 (InputLayer)          [(None, 60, 5)]              0         []
#
#  aws_3 (InputLayer)          [(None, 60, 5)]              0         []
#
#  conv1d (Conv1D)             (None, 58, 64)               1024      ['aws_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 58, 64)               1024      ['aws_2[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 58, 64)               1024      ['aws_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 29, 64)               0         ['conv1d[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 29, 64)               0         ['conv1d_1[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 29, 64)               0         ['conv1d_2[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 1856)                 0         ['max_pooling1d[0][0]']
#
#  flatten_1 (Flatten)         (None, 1856)                 0         ['max_pooling1d_1[0][0]']
#
#  flatten_2 (Flatten)         (None, 1856)                 0         ['max_pooling1d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 5568)                 0         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]',
#                                                                      'flatten_2[0][0]']
#
#  reshape (Reshape)           (None, 3, 1856)              0         ['concatenate[0][0]']
#
#  lstm (LSTM)                 (None, 32)                   241792    ['reshape[0][0]']
#
#  water (Dense)               (None, 1)                    33        ['lstm[0][0]']
#
# ==================================================================================================
# Total params: 244897 (956.63 KB)
# Trainable params: 244897 (956.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # 학습

# %%
model.fit([test_df1_re, test_df2_re, test_df3_re], test_wdf_z, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 546/546 [==============================] - 12s 16ms/step - loss: 0.0031 - mae: 0.0359
# Epoch 2/100
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0017 - mae: 0.0296
# Epoch 3/100
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0015 - mae: 0.0285
# Epoch 4/100
# 546/546 [==============================] - 12s 22ms/step - loss: 0.0012 - mae: 0.0264
# Epoch 5/100
# 546/546 [==============================] - 9s 16ms/step - loss: 0.0011 - mae: 0.0251
# Epoch 6/100
# 546/546 [==============================] - 10s 18ms/step - loss: 0.0010 - mae: 0.0240
# Epoch 7/100
# 546/546 [==============================] - 10s 18ms/step - loss: 8.7495e-04 - mae: 0.0226
# Epoch 8/100
# 546/546 [==============================] - 10s 17ms/step - loss: 8.3256e-04 - mae: 0.0217
# Epoch 9/100
# 546/546 [==============================] - 9s 16ms/step - loss: 6.8058e-04 - mae: 0.0201
# Epoch 10/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.9249e-04 - mae: 0.0201
# Epoch 11/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.0398e-04 - mae: 0.0189
# Epoch 12/100
# 546/546 [==============================] - 9s 16ms/step - loss: 5.4340e-04 - mae: 0.0179
# Epoch 13/100
# 546/546 [==============================] - 10s 18ms/step - loss: 5.2893e-04 - mae: 0.0173
# Epoch 14/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.5308e-04 - mae: 0.0163
# Epoch 15/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.0801e-04 - mae: 0.0155
# Epoch 16/100
# 546/546 [==============================] - 9s 16ms/step - loss: 3.8826e-04 - mae: 0.0149
# Epoch 17/100
# 546/546 [==============================] - 10s 18ms/step - loss: 3.5844e-04 - mae: 0.0142
# Epoch 18/100
# 546/546 [==============================] - 10s 18ms/step - loss: 3.2402e-04 - mae: 0.0136
# Epoch 19/100
# 546/546 [==============================] - 9s 16ms/step - loss: 3.0382e-04 - mae: 0.0131
# Epoch 20/100
# 546/546 [==============================] - 10s 17ms/step - loss: 2.9025e-04 - mae: 0.0126
# Epoch 21/100
# 546/546 [==============================] - 10s 18ms/step - loss: 2.6905e-04 - mae: 0.0122
# Epoch 22/100
# 546/546 [==============================] - 10s 18ms/step - loss: 2.2927e-04 - mae: 0.0114
# Epoch 23/100
# 546/546 [==============================] - 8s 16ms/step - loss: 2.1236e-04 - mae: 0.0109
# Epoch 24/100
# 546/546 [==============================] - 10s 18ms/step - loss: 2.1158e-04 - mae: 0.0107
# Epoch 25/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.7504e-04 - mae: 0.0099
# Epoch 26/100
# 546/546 [==============================] - 9s 16ms/step - loss: 1.8127e-04 - mae: 0.0099
# Epoch 27/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.9686e-04 - mae: 0.0103
# Epoch 28/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.7161e-04 - mae: 0.0094
# Epoch 29/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.5283e-04 - mae: 0.0090
# Epoch 30/100
# 546/546 [==============================] - 9s 16ms/step - loss: 1.4802e-04 - mae: 0.0089
# Epoch 31/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.2481e-04 - mae: 0.0082
# Epoch 32/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.2264e-04 - mae: 0.0082
# Epoch 33/100
# 546/546 [==============================] - 9s 17ms/step - loss: 1.3106e-04 - mae: 0.0083
# Epoch 34/100
# 546/546 [==============================] - 9s 16ms/step - loss: 1.2927e-04 - mae: 0.0082
# Epoch 35/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.2321e-04 - mae: 0.0080
# Epoch 36/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.0420e-04 - mae: 0.0074
# Epoch 37/100
# 546/546 [==============================] - 8s 16ms/step - loss: 1.0447e-04 - mae: 0.0075
# Epoch 38/100
# 546/546 [==============================] - 10s 18ms/step - loss: 9.8481e-05 - mae: 0.0072
# Epoch 39/100
# 546/546 [==============================] - 10s 18ms/step - loss: 1.0935e-04 - mae: 0.0074
# Epoch 40/100
# 546/546 [==============================] - 9s 16ms/step - loss: 1.0553e-04 - mae: 0.0073
# Epoch 41/100
# 546/546 [==============================] - 9s 17ms/step - loss: 1.1311e-04 - mae: 0.0073
# Epoch 42/100
# 546/546 [==============================] - 10s 18ms/step - loss: 9.3398e-05 - mae: 0.0068
# Epoch 43/100
# 546/546 [==============================] - 10s 18ms/step - loss: 8.0832e-05 - mae: 0.0065
# Epoch 44/100
# 546/546 [==============================] - 9s 16ms/step - loss: 8.7570e-05 - mae: 0.0068
# Epoch 45/100
# 546/546 [==============================] - 10s 18ms/step - loss: 9.0645e-05 - mae: 0.0067
# Epoch 46/100
# 546/546 [==============================] - 10s 18ms/step - loss: 7.6413e-05 - mae: 0.0063
# Epoch 47/100
# 546/546 [==============================] - 10s 18ms/step - loss: 8.7011e-05 - mae: 0.0067
# Epoch 48/100
# 546/546 [==============================] - 9s 16ms/step - loss: 7.8350e-05 - mae: 0.0062
# Epoch 49/100
# 546/546 [==============================] - 10s 18ms/step - loss: 7.5588e-05 - mae: 0.0063
# Epoch 50/100
# 546/546 [==============================] - 10s 18ms/step - loss: 7.7285e-05 - mae: 0.0062
# Epoch 51/100
# 546/546 [==============================] - 9s 16ms/step - loss: 7.6131e-05 - mae: 0.0061
# Epoch 52/100
# 546/546 [==============================] - 9s 17ms/step - loss: 8.8740e-05 - mae: 0.0066
# Epoch 53/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.4953e-05 - mae: 0.0057
# Epoch 54/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.9647e-05 - mae: 0.0059
# Epoch 55/100
# 546/546 [==============================] - 9s 16ms/step - loss: 6.8632e-05 - mae: 0.0059
# Epoch 56/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.6207e-05 - mae: 0.0057
# Epoch 57/100
# 546/546 [==============================] - 10s 18ms/step - loss: 7.2757e-05 - mae: 0.0059
# Epoch 58/100
# 546/546 [==============================] - 9s 17ms/step - loss: 6.7649e-05 - mae: 0.0058
# Epoch 59/100
# 546/546 [==============================] - 9s 17ms/step - loss: 5.3523e-05 - mae: 0.0053
# Epoch 60/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.7813e-05 - mae: 0.0058
# Epoch 61/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.8926e-05 - mae: 0.0058
# Epoch 62/100
# 546/546 [==============================] - 9s 16ms/step - loss: 6.0436e-05 - mae: 0.0054
# Epoch 63/100
# 546/546 [==============================] - 10s 18ms/step - loss: 7.2847e-05 - mae: 0.0058
# Epoch 64/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.5065e-05 - mae: 0.0048
# Epoch 65/100
# 546/546 [==============================] - 9s 17ms/step - loss: 5.8900e-05 - mae: 0.0054
# Epoch 66/100
# 546/546 [==============================] - 9s 17ms/step - loss: 4.9033e-05 - mae: 0.0050
# Epoch 67/100
# 546/546 [==============================] - 10s 18ms/step - loss: 5.1768e-05 - mae: 0.0051
# Epoch 68/100
# 546/546 [==============================] - 10s 18ms/step - loss: 8.8894e-05 - mae: 0.0062
# Epoch 69/100
# 546/546 [==============================] - 9s 16ms/step - loss: 4.9789e-05 - mae: 0.0049
# Epoch 70/100
# 546/546 [==============================] - 10s 18ms/step - loss: 3.9081e-05 - mae: 0.0045
# Epoch 71/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.5025e-05 - mae: 0.0048
# Epoch 72/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.7648e-05 - mae: 0.0049
# Epoch 73/100
# 546/546 [==============================] - 9s 16ms/step - loss: 6.5589e-05 - mae: 0.0056
# Epoch 74/100
# 546/546 [==============================] - 10s 18ms/step - loss: 5.4035e-05 - mae: 0.0051
# Epoch 75/100
# 546/546 [==============================] - 10s 18ms/step - loss: 6.0079e-05 - mae: 0.0052
# Epoch 76/100
# 546/546 [==============================] - 9s 17ms/step - loss: 5.3177e-05 - mae: 0.0051
# Epoch 77/100
# 546/546 [==============================] - 9s 17ms/step - loss: 3.8078e-05 - mae: 0.0044
# Epoch 78/100
# 546/546 [==============================] - 10s 18ms/step - loss: 5.7079e-05 - mae: 0.0052
# Epoch 79/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.5550e-05 - mae: 0.0047
# Epoch 80/100
# 546/546 [==============================] - 9s 16ms/step - loss: 4.5081e-05 - mae: 0.0047
# Epoch 81/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.4432e-05 - mae: 0.0047
# Epoch 82/100
# 546/546 [==============================] - 10s 18ms/step - loss: 3.9562e-05 - mae: 0.0045
# Epoch 83/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.5106e-05 - mae: 0.0047
# Epoch 84/100
# 546/546 [==============================] - 9s 16ms/step - loss: 4.0657e-05 - mae: 0.0045
# Epoch 85/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.7324e-05 - mae: 0.0047
# Epoch 86/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.4785e-05 - mae: 0.0046
# Epoch 87/100
# 546/546 [==============================] - 9s 17ms/step - loss: 4.0409e-05 - mae: 0.0045
# Epoch 88/100
# 546/546 [==============================] - 9s 17ms/step - loss: 4.1677e-05 - mae: 0.0046
# Epoch 89/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.4403e-05 - mae: 0.0046
# Epoch 90/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.3669e-05 - mae: 0.0046
# Epoch 91/100
# 546/546 [==============================] - 9s 16ms/step - loss: 3.3426e-05 - mae: 0.0041
# Epoch 92/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.4324e-05 - mae: 0.0046
# Epoch 93/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.2287e-05 - mae: 0.0045
# Epoch 94/100
# 546/546 [==============================] - 10s 18ms/step - loss: 3.5748e-05 - mae: 0.0042
# Epoch 95/100
# 546/546 [==============================] - 9s 16ms/step - loss: 3.9563e-05 - mae: 0.0044
# Epoch 96/100
# 546/546 [==============================] - 10s 18ms/step - loss: 5.3050e-05 - mae: 0.0049
# Epoch 97/100
# 546/546 [==============================] - 10s 18ms/step - loss: 2.9672e-05 - mae: 0.0039
# Epoch 98/100
# 546/546 [==============================] - 9s 17ms/step - loss: 3.0230e-05 - mae: 0.0039
# Epoch 99/100
# 546/546 [==============================] - 9s 17ms/step - loss: 3.6127e-05 - mae: 0.0042
# Epoch 100/100
# 546/546 [==============================] - 10s 18ms/step - loss: 4.0289e-05 - mae: 0.0044

# %% [markdown]
# # 결과

# %%
predictions = model.predict([test_df1_re, test_df2_re, test_df3_re])
# Out:
# 546/546 [==============================] - 4s 8ms/step

# %%
predictions_scale = scaler.inverse_transform(predictions)

# %%
predictions_scale.shape
# Out:
# (17461, 1)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(predictions_scale, label='Predicted', color = 'b', alpha=0.7)
plt.plot(test_wdf, label='Actual', color = 'y', alpha=0.7)

plt.xlabel('Time Step')
plt.ylabel('Water Level')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()

# %%
predictions_scale[:10]
# Out:
# array([[0.5955068 ],
#        [0.59100413],
#        [0.59740114],
#        [0.59287804],
#        [0.59951854],
#        [0.60699874],
#        [0.6055426 ],
#        [0.60411566],
#        [0.60287565],
#        [0.60142976]], dtype=float32)

# %% [markdown]
# - 모델저장

# %%
model.save("model_test(60)_cnn.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from pickle import dump

dump(scaler, open('./60_cnn_scaler.pkl', 'wb'))

# %% [markdown]
# # 모델 테스트

# %% [markdown]
# - 걍다시 ㄱ

# %%
t1 = pd.read_csv('11111.csv')

# %%
t2 = pd.read_csv('22222.csv')

# %%
t3 = pd.read_csv('33333.csv')

# %%
tw = pd.read_csv('test수위48.csv')

# %%
test_w = tw[["수위"]].values

# %%
from keras.models import load_model

model_filename = 'model_test(60)_cnn.h5'

loaded_model = load_model(model_filename)

# %%
from pickle import load

load_minmax_scaler = load(open('60_cnn_scaler.pkl', 'rb'))

# %% [markdown]
# ## 데이터 전처리

# %%
features = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

# %%
test_t1 = t1[features].values
test_t2 = t2[features].values
test_t3 = t3[features].values

# %% [markdown]
# ### 정규화

# %%
# 정규화
scaler = MinMaxScaler()

# 상류 하천 데이터 정규화
test_df1_z = scaler.fit_transform(test_t1)
test_df2_z = scaler.fit_transform(test_t2)
test_df3_z = scaler.fit_transform(test_t3)

# %%
time_steps = 48

new_data = []

for i in range(len(test_df1_z) - time_steps + 1):
    batch = test_df1_z[i:i+time_steps]
    new_data.append(batch)

test_df1_re = np.array(new_data)

# %%
test_df1_re.shape
# Out:
# (25, 48, 5)

# %%
new_data = []

for i in range(len(test_df2_z) - time_steps + 1):
    batch = test_df2_z[i:i+time_steps]
    new_data.append(batch)

test_df2_re = np.array(new_data)

# %%
new_data = []

for i in range(len(test_df3_z) - time_steps + 1):
    batch = test_df3_z[i:i+time_steps]
    new_data.append(batch)

test_df3_re = np.array(new_data)

# %% [markdown]
# ### 결과

# %%
predictions = loaded_model.predict([test_df1_re, test_df2_re, test_df3_re])
# Out:
# 1/1 [==============================] - 0s 252ms/step

# %%
predictions

# %%
predictions_scaler = load_minmax_scaler.inverse_transform(predictions)

# %%
predictions_scaler
# Out:
# array([[0.47555807],
#        [0.5576896 ],
#        [0.5862413 ],
#        [0.5750251 ],
#        [0.5809162 ],
#        [0.58277726],
#        [0.631615  ],
#        [0.63849574],
#        [0.697653  ],
#        [0.6972739 ],
#        [0.6980707 ],
#        [0.6972687 ],
#        [0.7007477 ],
#        [0.7203783 ],
#        [0.7078872 ],
#        [0.7281587 ],
#        [0.7202893 ],
#        [0.6933413 ],
#        [0.6567633 ],
#        [0.5201135 ],
#        [0.5412229 ],
#        [0.58299375],
#        [0.6062502 ],
#        [0.5547263 ],
#        [0.55971223]], dtype=float32)

# %%
predictions_scaler.shape
# Out:
# (25, 1)

# %%
test_w
# Out:
# array([[0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.66],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.65],
#        [0.66]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(predictions_scaler, label='Predicted', color = 'b', alpha=0.7)
plt.plot(test_w, label='Actual', color = 'y', alpha=0.7)

plt.xlabel('Time Step')
plt.ylabel('Water Level')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()

# %% [markdown]
# ## 3시간 테스트
# -> 27개의데이터

# %%
t1 = pd.read_csv('test60-1.csv')

# %%
t2 = pd.read_csv('test60-2.csv')

# %%
t3 = pd.read_csv('test60-3.csv')

# %%
features = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '습도(%)']

# %%
t3
# Out:
#      지점 지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  현지기압(hPa)  \
# 0   768  곡성  2023-08-28 00:00    24.2      0.0      0.3      0.0      996.9
# 1   768  곡성  2023-08-28 01:00    23.6    192.0      0.8      0.0      996.7
# 2   768  곡성  2023-08-28 02:00    23.4     10.4      1.1      0.0      996.5
# 3   768  곡성  2023-08-28 03:00    22.9      0.0      0.3      0.0      996.3
# 4   768  곡성  2023-08-28 04:00    23.0    307.4      0.5      0.0      996.2
# ..  ...  ..               ...     ...      ...      ...      ...        ...
# 57  768  곡성  2023-08-30 09:00    21.6      0.0      0.4      7.0      998.6
# 58  768  곡성  2023-08-30 10:00    21.9    200.4      0.5      8.5      998.3
# 59  768  곡성  2023-08-30 11:00    21.7    173.5      0.8     17.0      998.9
# 60  768  곡성  2023-08-30 12:00    21.8      0.0      0.0     28.5      998.4
# 61  768  곡성  2023-08-30 13:00    23.1      0.0      0.0      2.0      998.1
#
#     해면기압(hPa)  습도(%)
# 0      1008.3     97
# 1      1008.1     99
# 2      1007.9     99
# 3      1007.7     99
# 4      1007.6     98
# ..        ...    ...
# 57     1010.1    100
# 58     1009.8    100
# 59     1010.4    100
# 60     1009.9    100
# 61     1009.5    100
#
# [62 rows x 10 columns]

# %%
test_t1 = t1[features].values
test_t2 = t2[features].values
test_t3 = t3[features].values

# %%
# 정규화
scaler = MinMaxScaler()

# 상류 하천 데이터 정규화
test_df1_z = scaler.fit_transform(test_t1)
test_df2_z = scaler.fit_transform(test_t2)
test_df3_z = scaler.fit_transform(test_t3)

# %%
time_steps = 60

new_data = []

for i in range(len(test_df1_z) - time_steps + 1):
    batch = test_df1_z[i:i+time_steps]
    new_data.append(batch)

test_df1_re = np.array(new_data)

# %%
new_data = []

for i in range(len(test_df2_z) - time_steps + 1):
    batch = test_df2_z[i:i+time_steps]
    new_data.append(batch)

test_df2_re = np.array(new_data)

# %%
new_data = []

for i in range(len(test_df3_z) - time_steps + 1):
    batch = test_df3_z[i:i+time_steps]
    new_data.append(batch)

test_df3_re = np.array(new_data)

# %%
test_df3_re.shape
# Out:
# (3, 60, 5)

# %%
test_df3_re

# %%
predictions_t3 = loaded_model.predict([test_df1_re, test_df2_re, test_df3_re])
# Out:
# 1/1 [==============================] - 0s 250ms/step

# %%
predictions_t3
# Out:
# array([[0.1082271 ],
#        [0.18298686],
#        [0.26670057]], dtype=float32)

# %%
predictions_scaler_3 = load_minmax_scaler.inverse_transform(predictions_t3)

# %%
predictions_scaler_3
# Out:
# array([[0.72732097],
#        [0.9119776 ],
#        [1.1187505 ]], dtype=float32)

# %%
test_w = np.array([[2.18], [2.11], [2.04]])

# %%
tw1 = pd.read_csv('test수위48-1.csv')

# %%
test_w = tw1[["수위"]].values

# %%
test_w
# Out:
# array([[2.18],
#        [2.11],
#        [2.04]])

# %%
# RMSE
rmse = np.sqrt(((predictions_scaler_3 - test_w) ** 2).mean())

# MAE
mae = np.abs(predictions_scaler_3 - test_w).mean()

print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# RMSE: 1.2102664708794344
# MAE: 1.1906503295898438

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(predictions_scaler_3, label='Predicted', color = 'b', alpha=0.7)
plt.plot(test_w, label='Actual', color = 'y', alpha=0.7)

plt.xlabel('Time Step')
plt.ylabel('Water Level')
plt.title('Predicted vs Actual')
plt.legend()
plt.show()

# %%
predictions_scaler_3
# Out:
# array([[1.0374911 ],
#        [0.90322655],
#        [1.0528685 ]], dtype=float32)

# %%
# 데이터 포인트 레이블
data_labels = ['15:00', '16:00', '17:00']

# 그래프 데이터
x = np.arange(len(data_labels))
width = 0.35

# 예측값과 실제값 막대 그래프 생성
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, predictions_scaler_3.flatten(), width, label='Predictions')
rects2 = ax.bar(x + width/2, test_w.flatten(), width, label='Actual')

# 레이블과 범례 설정
ax.set_xlabel('Time')
ax.set_ylabel('Water')
ax.set_title('Predicted vs Actual')
ax.set_xticks(x)
ax.set_xticklabels(data_labels)
ax.legend()

ax.legend(loc='lower right')

# 막대 위에 값 표시
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}', xy=(rect.get_x() + rect.get_width() / 2, height), xytext=(0, 3),
                    textcoords="offset points", ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.tight_layout()
plt.show()
